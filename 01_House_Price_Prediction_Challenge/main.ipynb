# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lprc = pd.read_csv("Train.csv", na_values="*")
lprc
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT
# 0         Owner                   0     0        2       BHK  1300.236407  \
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE
# ...

# %%
lprc_describle = lprc.describe()
lprc_describle
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT
# count        29451.000000  29451.000000  29451.000000  2.945100e+04  \
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE
# count   29451.000000  29451.000000  29451.000000  29451.000000  \
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
important_val[important_val.isnull().any(axis=1)]
important_val = important_val.dropna(axis=1)
important_val
# Out:
#          SQUARE_FT  TARGET(PRICE_IN_LACS)
# 0      1300.236407                   55.0
# 1      1275.000000                   51.0
# 2       933.159722                   43.0
# 3       929.921143                   62.5
# 4       999.009247                   60.5
# ...            ...                    ...
# 29446  2500.000000                   45.0
# 29447   769.230769                   16.0
# 29448  1022.641509                   27.1
# 29449   927.079009                   67.0
# 29450   896.774194                   27.8
#
# [29451 rows x 2 columns]

# %%
important_val.describe()
# Out:
#           SQUARE_FT  TARGET(PRICE_IN_LACS)
# count  2.945100e+04           29451.000000
# mean   1.980217e+04             142.898746
# std    1.901335e+06             656.880713
# min    3.000000e+00               0.250000
# 25%    9.000211e+02              38.000000
# 50%    1.175057e+03              62.000000
# 75%    1.550688e+03             100.000000
# max    2.545455e+08           30000.000000

# %%
print("\n\nSQUARE_FT")
print("Max  : ", important_val["SQUARE_FT"].max())
print("Mean : ", important_val["SQUARE_FT"].mean())
print("Var  : ", important_val["SQUARE_FT"].var())
print("SD   : ", important_val["SQUARE_FT"].std())
print("Median: ", important_val["SQUARE_FT"].median())
print("\n\nTARGET(PRICE_IN_LACS)")
print("Max  : ", important_val["TARGET(PRICE_IN_LACS)"].max())
print("Mean : ", important_val["TARGET(PRICE_IN_LACS)"].mean())
print("Var  : ", important_val["TARGET(PRICE_IN_LACS)"].var())
print("SD   : ", important_val["TARGET(PRICE_IN_LACS)"].std())
print("Median: ", important_val["TARGET(PRICE_IN_LACS)"].median())
# Out:
# SQUARE_FT
# Max  :  254545454.5
# Mean :  19802.170190334724
# Var  :  3615074449506.236
# SD   :  1901334.912503906
# Median:  1175.05675
#
#
# TARGET(PRICE_IN_LACS)
# Max  :  30000.0
# Mean :  142.8987457132186
# Var  :  431492.2708461551
# SD   :  656.8807127981115
# Median:  62.0
